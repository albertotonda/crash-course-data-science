# %% [markdown]
# # This is an example of a notebook
# You can write text cells in a notebook, and they use MarkDown syntax, see [this useful link](https://www.markdownguide.org/basic-syntax/) for the details. In MarkDown, you can also write equations following a LaTex syntax:
#
# \begin{equation}
# f(x,\hat{x}) = \frac{x_0 + 2}{\sum_i^n (x - \hat{x})^2}
# \end{equation}
#
# And of course, you can have Python cell: if you run them, you have the output immediately visualized below each cell.

# %%
a = 1
b = 2
print("The value of variable \"a\" is:", a)
# Out:
# The value of variable "a" is: 1

# %%
a = a + 1
print("The value of variable \"a\" is:", a)
# Out:
# The value of variable "a" is: 4

# %% [markdown]
# Now, try running the cell above multiple times. What is happening? Why?
#
# You can also create subsections in your notebook, see below.

# %% [markdown]
# ## This is a subsection
# All the cells below can be collapsed using the arrow on the left side, it makes it easier to navigate. Now, let's try some visualization using matplotlib and seaborn, you will see

# %%
# all this code has been generated by ChatGPT, I asked it to give me a comparison of matplotlib vs seaborn visualization

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#sns.set_style('darkgrid') # try uncommenting this on a second run of the same cell

# Generate random data (normal distribution)
np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=500)

# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# ---- Matplotlib Histogram ----
axes[0].hist(data, bins=30, color="skyblue", edgecolor="black", alpha=0.7)
axes[0].set_title("Matplotlib Histogram")
axes[0].set_xlabel("Value")
axes[0].set_ylabel("Frequency")

# ---- Seaborn Histogram ----
sns.histplot(data, bins=30, kde=True, color="coral", ax=axes[1])
axes[1].set_title("Seaborn Histogram")
axes[1].set_xlabel("Value")
axes[1].set_ylabel("Frequency")

# Show the plot
plt.tight_layout()
plt.show()
